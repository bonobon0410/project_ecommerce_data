# %%
import pandas as pd

# %%
custom = pd.read_csv('C:/Users/sominseob/Desktop/GH/project/Custom.csv')
# 회원: 클라이언트 ID, 성별, 연령대 - 내가 맡아서 알아오기
# 아웃라이어 날리고, 정규표현식 같은거 사용해서 한글 날리고, 연령대별로 유저 수 찾기 
# master = pd.read_csv('C:/Users/Carta/Desktop/GH/Master.csv')
# # 상품분류: 상품코드, 상품명, 상품 대분류명, 상품 중분류명, 상품 소분류명
# product = pd.read_csv('C:/Users/Carta/Desktop/GH/Product.csv')
# # 상품구매: 클라이언트 ID, 세션 ID, 히트일련번호, 상품코드, 상품추가정보, 상품브랜드, 단일상품금액, 구매건수 
# search1 = pd.read_csv('C:/Users/Carta/Desktop/GH/Search1.csv')
# # 검색어 1: 클라이언트 ID, 세션ID, 검색키워드명, 검색건수 
# search2 = pd.read_csv('C:/Users/Carta/Desktop/GH/Search2.csv')
# # 검색어 2: 세션일자, 검색키워드명, 검색건수
session = pd.read_csv('C:/Users/sominseob/Desktop/GH/project/Session.csv')
# # 세션: 클라이언트 ID, 세션 ID, 세션일련번호, 세션일자, 총페이지조회건수, 총세션시간값, 기기유형, 지역대분류, 지역중분류

# %%
session
# Out:
#          CLNT_ID   SESS_ID  SESS_SEQ   SESS_DT  TOT_PAG_VIEW_CT TOT_SESS_HR_V  \
# 0        5873599   8641867         9  20180509             82.0         1,890
# 1        5873599   6616320        21  20180611            105.0         1,604
# 2        5873599   5886172        40  20180624             41.0           632
# 3        5873884   1050889        15  20180913            160.0         1,035
# 4        5874461  10298270         5  20180412             13.0           298
# 5        5874701    608577        65  20180920             41.0           444
# 6        5874829   1666766        87  20180903             36.0           340
# 7        5874829   1670494        86  20180903            103.0           976
# 8        5874829   1694242        85  20180902            154.0         3,099
# 9        5874829   1559438        92  20180904             24.0           317
# 10       5874900  10229983         7  20180413            207.0         4,143
# ...

# %%
custom
# Out:
#         CLNT_ID CLNT_GENDER  CLNT_AGE
# 0       4830726           F        30
# 1       4830874           F        40
# 2       4830975           F        30
# 3       4831275           F        30
# 4       4825325           F        30
# 5       4825382           F        40
# 6       4825797           F        40
# 7       4825908           F        30
# 8       4825961           F        30
# 9       4840532           M        40
# 10      4840825           F        10
# 11      4843304           F        30
# 12      4843591           F        30
# 13      4843997           F        30
# 14      4846369           F        30
# 15      4846380           F        20
# 16      4846440           M        40
# 17      4846511           M        40
# 18      4846738           F        20
# 19      4846869           F        30
# 20      4847147           F        20
# 21      4839353           F        30
# 22      4839427           F        30
# 23      4839489           F        40
# ...

# %%
age = custom.CLNT_AGE
age.describe()
# Out:
# count    671679.000000
# mean         33.064946
# std           8.380882
# min          10.000000
# 25%          30.000000
# 50%          30.000000
# 75%          40.000000
# max          80.000000
# Name: CLNT_AGE, dtype: float64

# %%
age.value_counts()
# Out:
# 30    313600
# 40    216217
# 20     95297
# 50     36624
# 60      5256
# 10      3807
# 70       846
# 80        32
# Name: CLNT_AGE, dtype: int64

# %%
custom = custom[custom.CLNT_AGE != 70]
custom = custom[custom.CLNT_AGE != 80]
custom.head()
# Out:
#    CLNT_ID CLNT_GENDER  CLNT_AGE
# 0  4830726           F        30
# 1  4830874           F        40
# 2  4830975           F        30
# 3  4831275           F        30
# 4  4825325           F        30

# %%
custom2=custom.groupby('CLNT_GENDER').mean()

# %%
custom2
# Out:
#                   CLNT_ID   CLNT_AGE
# CLNT_GENDER
# F            3.372156e+06  32.828326
# M            3.361534e+06  34.078710
